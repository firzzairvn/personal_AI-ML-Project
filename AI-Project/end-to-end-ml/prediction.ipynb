# %% [markdown]
# # About Dataset
#
# ## Car Price Prediction Dataset Description
#
# This dataset contains **10,000 entries** created for the purpose of predicting car prices.
# Each row represents **information about a car and its price**.
#
# Dataset Source : https://www.kaggle.com/datasets/asinow/car-price-dataset/data
#
# ## Column Descriptions
#
# ### **1. Brand**
# Specifies the brand of the car (e.g., Toyota, BMW, Ford).
# **Example values:** `"Toyota"`, `"BMW"`, `"Mercedes"`
#
# ### **2. Model**
# Specifies the model of the car (e.g., Corolla, Focus, X5).
# **Example values:** `"Corolla"`, `"Focus"`, `"X5"`
#
# ### **3. Year**
# The production year of the car. Newer years typically indicate higher prices.
# **Example values:** `2005`, `2018`, `2023`
#
# ### **4. Engine_Size**
# Specifies the engine size in liters (L). Larger engines generally correlate with higher prices.
# **Example values:** `1.6`, `2.0`, `3.5`
#
# ### **5. Fuel_Type**
# Indicates the type of fuel used by the car:
# - **Petrol**: Cars running on gasoline.
# - **Diesel**: Cars running on diesel fuel.
# - **Hybrid**: Cars that use both fuel and electricity.
# - **Electric**: Fully electric cars.
#
# ### **6. Transmission**
# The type of transmission in the car:
# - **Manual**: Manual transmission.
# - **Automatic**: Automatic transmission.
# - **Semi-Automatic**: Semi-automatic transmission.
#
# ### **7. Mileage**
# The total distance the car has traveled, measured in kilometers.
# Lower mileage generally indicates a higher price.
# **Example values:** `15,000`, `75,000`, `230,000`
#
# ### **8. Doors**
# The number of doors in the car. Commonly **2, 3, 4, or 5** doors.
# **Example values:** `2`, `3`, `4`, `5`
#
# ### **9. Owner_Count**
# The number of previous owners of the car.
# Fewer owners generally indicate a higher price.
# **Example values:** `1`, `2`, `3`, `4`
#
# ### **10. Price**
# The estimated selling price of the car.
# It is calculated based on several factors such as **production year, engine size, mileage, fuel type, and transmission**.
# **Example values:** `5,000`, `15,000`, `30,000`

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np 
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('D:\Machine Learning\dataset\car_price.csv')
df
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 2       Mercedes       GLA  2020          4.2    Diesel       Automatic
# 3           Audi        Q5  2023          2.0  Electric          Manual
# 4     Volkswagen      Golf  2003          2.6    Hybrid  Semi-Automatic
# ...          ...       ...   ...          ...       ...             ...
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996   Chevrolet    Impala  2002          1.4  Electric       Automatic
# 9997         BMW  3 Series  2010          3.0    Petrol       Automatic
# 9998        Ford  Explorer  2002          1.4    Hybrid       Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944      3            5   8501
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         10000 non-null  object
#  1   Model         10000 non-null  object
#  2   Year          10000 non-null  int64
#  3   Engine_Size   10000 non-null  float64
#  4   Fuel_Type     10000 non-null  object
#  5   Transmission  10000 non-null  object
#  6   Mileage       10000 non-null  int64
#  7   Doors         10000 non-null  int64
#  8   Owner_Count   10000 non-null  int64
#  9   Price         10000 non-null  int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 781.4+ KB

# %%
check_missing = df.isnull().sum()
check_missing
# Out:
# Brand           0
# Model           0
# Year            0
# Engine_Size     0
# Fuel_Type       0
# Transmission    0
# Mileage         0
# Doors           0
# Owner_Count     0
# Price           0
# dtype: int64

# %%
df.describe()
# Out:
#                Year   Engine_Size        Mileage         Doors   Owner_Count  \
# count  10000.000000  10000.000000   10000.000000  10000.000000  10000.000000
# mean    2011.543700      3.000560  149239.111800      3.497100      2.991100
# std        6.897699      1.149324   86322.348957      1.110097      1.422682
# min     2000.000000      1.000000      25.000000      2.000000      1.000000
# 25%     2006.000000      2.000000   74649.250000      3.000000      2.000000
# 50%     2012.000000      3.000000  149587.000000      3.000000      3.000000
# 75%     2017.000000      4.000000  223577.500000      4.000000      4.000000
# max     2023.000000      5.000000  299947.000000      5.000000      5.000000
#
#              Price
# count  10000.00000
# mean    8852.96440
# std     3112.59681
# min     2000.00000
# 25%     6646.00000
# 50%     8858.50000
# 75%    11086.50000
# max    18301.00000

# %%
for col in ['Brand', 'Model', 'Fuel_Type', 'Transmission']:
    unique_values = df[col].unique()
    print(f"{col} has {len(unique_values)} unique categories")
    print(unique_values, "\n")
# Out:
# Brand has 10 unique categories
# ['Kia' 'Chevrolet' 'Mercedes' 'Audi' 'Volkswagen' 'Toyota' 'Honda' 'BMW'
#  'Hyundai' 'Ford']
#
# Model has 30 unique categories
# ['Rio' 'Malibu' 'GLA' 'Q5' 'Golf' 'Camry' 'Civic' 'Sportage' 'RAV4'
#  '5 Series' 'CR-V' 'Elantra' 'Tiguan' 'Equinox' 'Explorer' 'A3' '3 Series'
#  'Tucson' 'Passat' 'Impala' 'Corolla' 'Optima' 'Fiesta' 'A4' 'Focus'
#  'E-Class' 'Sonata' 'C-Class' 'X5' 'Accord']
#
# Fuel_Type has 4 unique categories
# ['Diesel' 'Hybrid' 'Electric' 'Petrol']
#
# Transmission has 3 unique categories
# ['Manual' 'Automatic' 'Semi-Automatic']

# %% [markdown]
# ### **Outlier Check & Remove**

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['Price'])
plt.subplot(1,2,2)
sns.distplot(df['Mileage'])
plt.show()

# %%
Q1 = df[['Mileage', 'Price']].quantile(0.25) #percentile 25
Q3 = df[['Mileage', 'Price']].quantile(0.75) #percentile 75
IQR = Q3 - Q1

# %%
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

# %%
df[df[['Mileage', 'Price']] > upper_limit]
df[df[['Mileage', 'Price']] < lower_limit]
# Out:
#      Brand Model  Year  Engine_Size Fuel_Type Transmission  Mileage  Doors  \
# 0      NaN   NaN   NaN          NaN       NaN          NaN      NaN    NaN
# 1      NaN   NaN   NaN          NaN       NaN          NaN      NaN    NaN
# 2      NaN   NaN   NaN          NaN       NaN          NaN      NaN    NaN
# 3      NaN   NaN   NaN          NaN       NaN          NaN      NaN    NaN
# 4      NaN   NaN   NaN          NaN       NaN          NaN      NaN    NaN
# ...    ...   ...   ...          ...       ...          ...      ...    ...
# 9995   NaN   NaN   NaN          NaN       NaN          NaN      NaN    NaN
# 9996   NaN   NaN   NaN          NaN       NaN          NaN      NaN    NaN
# 9997   NaN   NaN   NaN          NaN       NaN          NaN      NaN    NaN
# 9998   NaN   NaN   NaN          NaN       NaN          NaN      NaN    NaN
# 9999   NaN   NaN   NaN          NaN       NaN          NaN      NaN    NaN
#
#       Owner_Count  Price
# 0             NaN    NaN
# ...

# %%
outliers = ((df[['Mileage', 'Price']] < lower_limit) | (df[['Mileage', 'Price']] > upper_limit)).sum()
outliers
# Out:
# Mileage    0
# Price      6
# dtype: int64

# %%
df_cleaned = df[(df['Price'] >= lower_limit['Price']) & (df['Price'] <= upper_limit['Price'])]

# %%
df_cleaned.shape
# Out:
# (9994, 10)

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['Price'])
plt.subplot(2,2,2)
sns.boxplot(df['Mileage'])
plt.subplot(2,2,3)
sns.distplot(df_cleaned['Price'])
plt.subplot(2,2,4)
sns.boxplot(df_cleaned['Mileage'])
plt.show()

# %% [markdown]
# ### **Build Model Linear Regression**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df_cleaned = df_cleaned.drop(columns=['Brand', 'Model', 'Fuel_Type', 'Transmission', 'Owner_Count'], axis=1)

# %%
X = df_cleaned.drop('Price', axis=1)
y = df_cleaned['Price']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
predictions_df = pd.DataFrame({'Actual Price': y_test.values, 'Predicted Price': y_pred})
print(predictions_df.head())
# Out:
#    Actual Price  Predicted Price
# 0          9576      9850.565133
# 1          9403      9179.831092
# 2          8676      8935.651069
# 3          4411      5727.633055
# 4         13481     12727.197279

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared (R²): {r2:.2f}")
# Out:
# Mean Squared Error (MSE): 1198884.67
# R-squared (R²): 0.87

# %%
new_data = [[2022, 2.0, 50000, 4]]  # Contoh input: Tahun, Engine Size, Mileage, Doors
new_data_scaled = scaler.transform(new_data)  # Standarisasi data

predicted_price = model.predict(new_data_scaled)
print(f"Predicted Price: ${predicted_price[0]:,.2f}")
# Out:
# Predicted Price: $12,977.56

# %%
import joblib

joblib.dump(model, 'car_prediction.pkl')
# Out:
# ['car_prediction.pkl']

# %%
import joblib
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']
